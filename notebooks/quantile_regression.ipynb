# %%
from sklearn.linear_model import ElasticNet  # noqa: F401
from sklearn.preprocessing import StandardScaler  # noqa: F401

# %% [markdown]
# # Quantile Regression
#
# All you need to know is [here](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.QuantileRegressor.html)
# and an [example](https://scikit-learn.org/stable/modules/linear_model.html#quantile-regression)
