# %%
import pandas as pd
from pathlib import Path
from sklearn.cross_decomposition import PLSRegression  # noqa: F401
from sklearn.preprocessing import StandardScaler  # noqa: F401
from IPython.display import display

# %% [markdown]
# # Partial Least Squares Regression (PLSR) for Drug Analysis
#
# ## Task is perform and present PLS analysis. No need for prediction of regression tasks.
#
# Here is all you need to know [Scikit-Learn Reference](https://scikit-learn.org/stable/modules/generated/sklearn.cross_decomposition.PLSRegression.html#sklearn.cross_decomposition.PLSRegression)
# and an [Example](https://scikit-learn.org/stable/auto_examples/cross_decomposition/plot_compare_cross_decomposition.html#sphx-glr-auto-examples-cross-decomposition-plot-compare-cross-decomposition-py)

# %%
data_path = Path.cwd().parent / "data" / "pls_regression"
hallucinome = pd.read_csv(data_path / "hallucinome.csv")
antipsychotics = pd.read_csv(data_path / "antipsychotics.csv")

# %%
display(hallucinome)
display(antipsychotics)
