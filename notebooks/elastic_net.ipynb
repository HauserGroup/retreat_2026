# %%
# ruff: noqa F401

import pandas as pd

from utils import data_path
from sklearn.linear_model import ElasticNetCV, LassoCV, RidgeCV
from sklearn.preprocessing import StandardScaler
from sklearn.dummy import DummyRegressor
from IPython.display import display

# %% [markdown]
# # ElasticNet
#
# ### 0) Data
# Data is "Food liking" data from Jakob's pet project. See [Liking for avocados](https://biobank.ndph.ox.ac.uk/showcase/field.cgi?id=20606) for more info. Columns are "Mediterranean" factor salient items.
#
# ## 1) Try this
# Fit an ElasticNet model to a regression dataset and see what kind of coefficient pattern you get. It can be fun to notice which features get shrunk a lot and which ones hang on.
#
# - All you need to know is [here](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.ElasticNet.html)
# - and an [example](https://scikit-learn.org/stable/auto_examples/linear_model/plot_lasso_and_elasticnet.html)
#
# ## 2) Tune 1 parameter
# Try different values of `alpha` and see how strongly the coefficients are shrunk.
#
# ## 3) Bonus
# See if you outperform DummyRegressor, teach Hauser group about the magnificent DummyRegressor

# %%
data_path = Path.cwd().parent / "data" / "elastic_net"
df = pd.read_csv(data_path / "taste_samples.csv", index_col=0)
display(df)
# Out:
#      AGE ANCESTRY  BlackOlives  GreenOlives  BlueCheese  Avocados  GoatCheese  \
# SEX
# 1     40      CSA            7            8           6         8           6
# 0     67      CSA            8            9           6         5           6
# 0     58      AMR            8            6           4         9           8
# 0     64      AFR            3            6           5         5           7
# 1     43      CSA            6            6           7         7           6
# ..   ...      ...          ...          ...         ...       ...         ...
# 0     41      EUR            5            5           1         9           7
# 0     55      EUR            1            1           1         1           6
# 0     47      EUR            9            8           8         9           9
# 0     59      EUR            7            7           9         9           6
# 0     62      EUR            1            1           9         5           7
#
# ...
