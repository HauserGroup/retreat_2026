# %%
# ruff: noqa F401

import pandas as pd

from utils import data_path

from sklearn.manifold import spectral_embedding
from sklearn.metrics import silhouette_score
from sklearn.cluster import SpectralClustering
from IPython.display import display

# %% [markdown]
# # Spectral Clustering
#
# ## 0) Data
#
#
# ## 1) The fun part
# See what happens when you cluster an affinity matrix(graph) with Spectral Clustering. For plotting, `spectral_embedding` is handy.
#
# - All you need to know is [here](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.SpectralClustering.html)
# - and an [example](https://scikit-learn.org/stable/modules/clustering.html#spectral-clustering)
# - You can also try the Silhouette score to get a feel for how tidy your clustering looks. [Here is how](https://scikit-learn.org/stable/modules/clustering.html#clustering-performance-evaluation)
#
# ## 2) Tune a parameter
# Try a few values of `n_clusters` and see how much the clustering changes.
#
# ## 3) Bonus
# If you’re curious, compare the Silhouette score for a few different values of `n_clusters`.

# %%
data = data_path("spectral_clustering", "adjacency_matrix.tsv")
df = pd.read_csv(data, index_col=0, sep="\t")
display(df)
# Out:
#              HTR2B-GNA14  OPRK1-GNAZ  LPAR4-GNA13  DRD2-GNAI2  OPRK1-GNAI1  \
# GPCR-Type
# HTR2B-GNA14            0           0            0           0            0
# OPRK1-GNAZ             0           0            0           0            1
# LPAR4-GNA13            0           0            0           0            0
# DRD2-GNAI2             0           0            0           0            0
# OPRK1-GNAI1            0           1            0           0            0
# ...                  ...         ...          ...         ...          ...
# HTR4-GNA13             0           0            0           1            0
# ADRA2B-GNAZ            0           0            0           0            0
# LPAR2-GNA14            0           0            0           0            0
# HRH1-GNAS              0           0            0           0            0
# DRD2-GNAI1             0           0            0           1            0
#
#              LPAR2-GNA15  BDKRB1-GNAQ  LPAR3-GNA14  DRD3-GNAI1  ADORA2B-GNAL  \
# GPCR-Type
# HTR2B-GNA14            0            0            0           0             0
# OPRK1-GNAZ             0            0            0           0             0
# LPAR4-GNA13            0            0            0           1             0
# DRD2-GNAI2             0            0            0           1             0
# OPRK1-GNAI1            0            0            0           0             0
# ...                  ...          ...          ...         ...           ...
# HTR4-GNA13             0            0            0           0             0
# ADRA2B-GNAZ            0            0            0           0             0
# LPAR2-GNA14            1            0            1           0             0
# HRH1-GNAS              0            0            0           0             0
# DRD2-GNAI1             0            0            0           1             0
#
#              ...  HTR1A-GNA15  LPAR1-GNA15  HTR2C-GNA12  HTR1E-GoB  \
# GPCR-Type    ...
# HTR2B-GNA14  ...            0            0            1          1
# OPRK1-GNAZ   ...            0            0            0          0
# LPAR4-GNA13  ...            0            0            0          0
# DRD2-GNAI2   ...            0            0            1          0
# OPRK1-GNAI1  ...            0            0            0          0
# ...          ...          ...          ...          ...        ...
# HTR4-GNA13   ...            0            0            0          0
# ADRA2B-GNAZ  ...            0            0            0          0
# LPAR2-GNA14  ...            0            1            0          0
# HRH1-GNAS    ...            0            0            0          0
# DRD2-GNAI1   ...            0            0            1          0
#
#              CCKAR-GNA11  HTR4-GNA13  ADRA2B-GNAZ  LPAR2-GNA14  HRH1-GNAS  \
# GPCR-Type
# HTR2B-GNA14            0           0            0            0          0
# OPRK1-GNAZ             0           0            0            0          0
# LPAR4-GNA13            0           0            0            0          0
# DRD2-GNAI2             0           1            0            0          0
# OPRK1-GNAI1            0           0            0            0          0
# ...                  ...         ...          ...          ...        ...
# HTR4-GNA13             0           0            0            0          0
# ADRA2B-GNAZ            0           0            0            0          0
# LPAR2-GNA14            0           0            0            0          0
# HRH1-GNAS              0           0            0            0          0
# DRD2-GNAI1             0           0            0            0          0
#
#              DRD2-GNAI1
# GPCR-Type
# HTR2B-GNA14           0
# OPRK1-GNAZ            0
# LPAR4-GNA13           0
# DRD2-GNAI2            1
# OPRK1-GNAI1           0
# ...                 ...
# HTR4-GNA13            0
# ADRA2B-GNAZ           0
# LPAR2-GNA14           0
# HRH1-GNAS             0
# DRD2-GNAI1            0
#
# [644 rows x 644 columns]

# %%
row_names = df.index
mat = df.values
print(mat.shape)
# Out:
# (644, 644)
