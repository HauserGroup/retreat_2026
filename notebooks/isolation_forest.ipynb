# %%
import pandas as pd
from sklearn.ensemble import IsolationForest  # noqa: F401
from sklearn.preprocessing import StandardScaler  # noqa: F401
from IPython.display import display
from pathlib import Path

# %% [markdown]
# # Isolation Forest
#
# ## Task is identifying outlying receptors from tissue expression
#
# All you need to know is [here](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.IsolationForest.html)
# and an [example](https://scikit-learn.org/stable/modules/outlier_detection.html#isolation-forest)

# %%
data_path = Path.cwd().parent / "data" / "isolation_forest"
gtex = pd.read_csv(
    data_path / "GTEx_Analysis_gene_median_tpm_filtered.csv", index_col=0
)

# %%
display(gtex)
# Out:
#          Adipose_Subcutaneous  Adipose_Visceral_Omentum  Adrenal_Gland  \
# Name
# HTR6                 0.093214                  0.072050       0.029662
# HTR1D                0.015062                  0.022327       0.016925
# CNR2                 0.025420                  0.038305       0.012707
# PTAFR                5.414530                  7.416020       3.091140
# OPRD1                0.048392                  0.079741       0.038999
# ...                       ...                       ...            ...
# CYSLTR1              2.393230                  2.063070       0.420629
# LPAR4                0.420073                  0.821064       0.042559
# HTR2C                0.000000                  0.000000       0.000000
# GPR119               0.000000                  0.000000       0.000000
# AVPR2               14.672100                 10.499600       0.313972
#
#          Artery_Aorta  Artery_Coronary  Artery_Tibial   Bladder  \
# Name
# ...
