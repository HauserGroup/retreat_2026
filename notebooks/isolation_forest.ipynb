# %%
# ruff: noqa F401

import pandas as pd

from utils import data_path

from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
from IPython.display import display

# %% [markdown]
# # Isolation Forest
#
# ### 0) Data
# Bulk median tissue expression data from [GTEx](https://www.gtexportal.org/home/downloads/adult-gtex/bulk_tissue_expression) for some random GPCRs
#
# ### 1) The fun part
# Fit an `IsolationForest` model and see which observations get flagged as outliers. There is usually at least one point that looks a little suspicious.
#
# - All you need to know is [here](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.IsolationForest.html)
# - and an [example](https://scikit-learn.org/stable/auto_examples/ensemble/plot_isolation_forest.html)
#
# ### 2) Tune 1 parameter
# Try different values of `contamination` and see how the number of detected outliers changes.
#
# ### 3) Bonus
# If you’re in the mood for a quick extra plot, look at the anomaly scores and find the most unusual observations.

# %%
data = data_path("isolation_forest", "GTEx_Analysis_gene_median_tpm_filtered.csv")
gtex = pd.read_csv(data, index_col=0)

# %%
display(gtex)
